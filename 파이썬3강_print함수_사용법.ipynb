# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeon0677/ABCD-A/blob/20250310/%ED%8C%8C%EC%9D%B4%EC%8D%AC3%EA%B0%95_print%ED%95%A8%EC%88%98_%EC%82%AC%EC%9A%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
print('hello', 'everyone')
print('hello'+'everyone')

print('hello', end=' ')
print('test')

a = 123
b = 'hello'
print(a,b)
print(a,456,b,'world')

print('Hello "Python"')
print("Hello 'Python'")
print('Hello','Python!')
print('Hello'+'Python!')

print("화면에 직접 출력")
print('ab\'c')
print("ab'c")
print("doesn't")
print('does')
print('doesn\'t')
print("'string'")
print("\"string\"")
print('"string"')

s1 = '화면에 직접 출력'
s2 = 'ab\'c'
s3 = 'does'
print(s1)
print(s2)
print(s3)
print(s1[0]) #첫 글자
print(s2[1]) #두 번째 글자
print(s3[1:3]) #두 번째, 네 번째 글자
print(s3[-1]) #마지막 글자
print(s3[-2]) #뒤에서 두 번째 글자

a = 2
b = 3.1456
c = a+b
print(a)
print(b)
print(c)
print(round(c, 3)) #소수점 자릿수 지정, 소수점 뒷자리에서 반올
print("%.3f" % (c))  #소수점 자릿수 지정
print(a+b)
print(a,b,a+b,c)
d = 1e2
e = 1e-2
print(d)
print(e)

item1 = '사과'
price1 = 1000
item2 = '바나나'
price2 = 500
print(item1, price1)
print(item2, price2)

item1 = '사과'
price1 = 1000
item2 = '바나나'
price2 = 500
str1 = "{0}는 {1}원입니다."
print(str1.format(item1, price1))
print(str1.format(item2, price2))

item1 = '사과'
price1 = 1000
item2 = '바나나'
price2 = 500
print(item1, price1, sep=',', end='/') #sep으로 사과와 1000 사이에 공백 대신 ,를 넣음
print(item2, price2)

item1 = '사과'
price1 = 1000
item2 = '바나나'
price2 = 500
str2 = '%s는 %d원입니다.'
print(str2%(item1, price1))
print(str2%(item2, price2))
# Out:
# Hello
# hello everyone
# helloeveryone
# hello test
# 123 hello
# 123 456 hello world
# Hello "Python"
# Hello 'Python'
# Hello Python!
# HelloPython!
# 화면에 직접 출력
# ab'c
# ab'c
# doesn't
# does
# doesn't
# 'string'
# "string"
# "string"
# 화면에 직접 출력
# ab'c
# does
# 화
# b
# oe
# s
# e
# 2
# 3.1456
# 5.1456
# 5.146
# 5.146
# 5.1456
# 2 3.1456 5.1456 5.1456
# 100.0
# 0.01
# 사과 1000
# 바나나 500
# 사과는 1000원입니다.
# 바나나는 500원입니다.
# 사과,1000/바나나 500
# 사과는 1000원입니다.
# 바나나는 500원입니다.
