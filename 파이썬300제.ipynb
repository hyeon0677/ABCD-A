# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeon0677/ABCD-A/blob/20250310/%ED%8C%8C%EC%9D%B4%EC%8D%AC300%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Marry's cosmetics")
# Out:
# Marry's cosmetics

# %%
print('신씨가 소리를 질렀다. "도둑이야."')
# Out:
# 신씨가 소리를 질렀다. "도둑이야."

# %%
print('"C:\\windows"')
# Out:
# "C:\windows"

# %%
print('안녕하세요. \n만나서\t\t반갑습니다')
# Out:
# 안녕하세요.
# 만나서		반갑습니다

# %%
print("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
print("naver;kakao;sk;samsung")
print("naver","kakao","sk","samsung", sep=";")
# Out:
# naver;kakao;sk;samsung
# naver;kakao;sk;samsung

# %%
print("naver","kakao","sk","samsung", sep="/")
# Out:
# naver/kakao/sk/samsung

# %%
print("first", end="");print("second")
# Out:
# firstsecond

# %%
print(5/3)
# Out:
# 1.6666666666666667
